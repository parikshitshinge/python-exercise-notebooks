# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
#wbst = 'https://en.wikipedia.org/wiki/List_of_all-time_NHL_standings'
#webbrowser.open(wbst)

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1920  NFC North
# 2              1921  NFC North
# 3              1960   AFC East
# 4              1966   AFC East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
 nfl_frame.Team
# Out:
# 0             Dallas Cowboys
# 1              Chicago Bears
# 2          Green Bay Packers
# 3    New England Patriots[b]
# 4             Miami Dolphins
# Name: Team, dtype: object

# %%
nfl_frame['Team']
# Out:
# 0             Dallas Cowboys
# 1              Chicago Bears
# 2          Green Bay Packers
# 3    New England Patriots[b]
# 4             Miami Dolphins
# Name: Team, dtype: object

# %%
# creating new data frame & displaing some columns from exisitng data frame
DataFrame(nfl_frame, columns=['Team', 'Rank', 'Total Games'])
# Out:
#                       Team  Rank  Total Games
# 0           Dallas Cowboys     1          NaN
# 1            Chicago Bears     2          NaN
# 2        Green Bay Packers     3          NaN
# 3  New England Patriots[b]     4          NaN
# 4           Miami Dolphins     5          NaN

# %%
DataFrame(nfl_frame, columns=['Team', 'Rank', 'Total Games', 'Stadium']) #Stadium is not present
# Out:
#                       Team  Rank  Total Games  Stadium
# 0           Dallas Cowboys     1          NaN      NaN
# 1            Chicago Bears     2          NaN      NaN
# 2        Green Bay Packers     3          NaN      NaN
# 3  New England Patriots[b]     4          NaN      NaN
# 4           Miami Dolphins     5          NaN      NaN

# %%
nfl_frame.head(3) #retriving first 3 rows, default is 5
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1     Dallas Cowboys    898  512   380     6  0.573              1960
# 1     2      Chicago Bears  1,386  761   583    42  0.564              1920
# 2     3  Green Bay Packers  1,352  743   571    38  0.564              1921
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  NFC North

# %%
nfl_frame.tail(3) #retriving last 3 rows, default is 5
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division
# 2              1921  NFC North
# 3              1960   AFC East
# 4              1966   AFC East

# %%
nfl_frame.loc[3] # retriving data using specific index
# Out:
# Rank                                      4
# Team                New England Patriots[b]
# GP                                      900
# Won                                     500
# Lost                                    391
# Tied                                      9
# Pct.                                  0.561
# First NFL Season                       1960
# Division                           AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium" #changing value in a column

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1920  NFC North  Levi's Stadium
# 2              1921  NFC North  Levi's Stadium
# 3              1960   AFC East  Levi's Stadium
# 4              1966   AFC East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5) # changing value of Stadium column

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division  Stadium
# 0              1960   NFC East        0
# 1              1920  NFC North        1
# 2              1921  NFC North        2
# 3              1960   AFC East        3
# 4              1966   AFC East        4

# %%
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[4,0])
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
# mapping stadiums series to our data frame (join on index)
nfl_frame['Stadium'] = stadiums
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East    AT&T Stadium
# 1              1920  NFC North             NaN
# 2              1921  NFC North             NaN
# 3              1960   AFC East             NaN
# 4              1966   AFC East  Levi's Stadium

# %%
#deleting a column from data frame
del nfl_frame['Stadium']
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    898  512   380     6  0.573
# 1     2            Chicago Bears  1,386  761   583    42  0.564
# 2     3        Green Bay Packers  1,352  743   571    38  0.564
# 3     4  New England Patriots[b]    900  500   391     9  0.561
# 4     5           Miami Dolphins    816  452   360     4  0.556
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1920  NFC North
# 2              1921  NFC North
# 3              1960   AFC East
# 4              1966   AFC East

# %%
# construct data frames by passing dictionary
data = {'City':['SF', 'LA', 'NYC'], 'Population':[83700,3880000,8400000]}

# %%
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF       83700
# 1   LA     3880000
# 2  NYC     8400000
